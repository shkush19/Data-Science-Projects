# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#importing of IRIS Dataset

iris_d=pd.read_csv(r'S:\Naresh IT\4th April\Prakash Sir Work\IRIS DATASET _ ADVANCE VISUALIZATION _ EDA 2\iris.csv')
iris_d
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# _______Display records_______

# %%
iris_d.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_d.drop('Id',axis=1,inplace=True)

# %%
iris_d.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_d.info()###identifying missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_d['Species'].value_counts()##Species has three variants
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
## Bar Plot

sns.countplot('Species', data=iris_d)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 ## Bar Plot
# ----> 3 sns.countplot('Species', data=iris_d)
#       4 plt.show()
#
# TypeError: countplot() got multiple values for argument 'data'

# %%
# Load iris dataset
iris = load_iris()
iris_d = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_d['Species'] = iris.target

# Using data as keyword argument
sns.countplot(data=iris_d, x='Species',)
plt.show()

# %%
iris = load_iris()
iris_d = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_d['Species'] = iris.target

# Define color palette
palette = sns.color_palette("husl", 3)  # You can choose any color palette you like

# Map numerical labels to category names
iris_d['Species'] = iris_d['Species'].map({0: iris.target_names[0], 1: iris.target_names[1], 2: iris.target_names[2]})

# Create countplot with specified palette
sns.countplot(data=iris_d, x='Species', palette=palette)
plt.show()

# %%
iris_d.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   Species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['Species'] = iris.target

# Define color palette
palette = sns.color_palette("husl", 3)  # You can choose any color palette you like

# Map numerical labels to category names
iris_df['Species'] = iris_df['Species'].map({0: iris.target_names[0], 1: iris.target_names[1], 2: iris.target_names[2]})

# Create countplot with specified palette
sns.countplot(data=iris_df, x='Species', palette=palette)
plt.show()

# %%
iris = load_iris()
iris_d = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_d['Species'] = iris.target

# Plotting the jointplot
fig = sns.jointplot(x='sepal length (cm)', y='sepal width (cm)', data=iris_d)
plt.show()

# %%
fig = sns.jointplot(x='sepal length (cm)', y='sepal width (cm)', data=iris_d, kind="reg")

# %%
fig = sns.jointplot(x='sepal length (cm)', y='sepal width (cm)', data=iris_d, kind="hex", color="Pink")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Assuming 'iris_d' is your DataFrame containing the iris dataset

# Map numerical labels to category names
iris_d['Species'] = iris.target_names[iris_d['Species']]

# Create FacetGrid
g = sns.FacetGrid(iris_d, hue='Species', height=5)
g.map(plt.scatter, 'sepal length (cm)', 'sepal width (cm)').add_legend()

# %%
iris_d.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   Species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxplot(x='Species',y='petal length (cm)',data=iris,order=['Iris-virginica','Iris-versicolor','Iris-setosa'],linewidth=2.5,orient='v',dodge=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 3
#       1 fig=plt.gcf()
#       2 fig.set_size_inches(10,7)
# ----> 3 fig=sns.boxplot(x='Species',y='petal length (cm)',data=iris,order=['Iris-virginica','Iris-versicolor','Iris-setosa'],linewidth=2.5,orient='v',dodge=False)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
# ...

# %%
# Load iris dataset
iris_d = load_iris()

# Create boxplot with specified order
fig = sns.boxplot(x='Species', y='petal length (cm)', data=iris_d, order=['Iris-virginica', 'Iris-versicolor', 'Iris-setosa'], linewidth=2.5, orient='v', dodge=False)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 5
#       2 iris_d = load_iris()
#       4 # Create boxplot with specified order
# ----> 5 fig = sns.boxplot(x='Species', y='petal length (cm)', data=iris_d, order=['Iris-virginica', 'Iris-versicolor', 'Iris-setosa'], linewidth=2.5, orient='v', dodge=False)
#       7 # Show the plot
#       8 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_iris

# Load iris dataset
iris = load_iris()
iris_d = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_d['Species'] = iris.target_names[iris.target]

# Create boxplot with specified order
fig = sns.boxplot(x='Species', y='petal length (cm)', data=iris_d, order=['setosa', 'versicolor', 'virginica'], linewidth=2.5, orient='v', dodge=False)

# Show the plot
plt.show()

# %%
iris_d.boxplot(by="Species", figsize=(12, 6))
# Out:
# array([[<Axes: title={'center': 'petal length (cm)'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'petal width (cm)'}, xlabel='[Species]'>],
#        [<Axes: title={'center': 'sepal length (cm)'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'sepal width (cm)'}, xlabel='[Species]'>]],
#       dtype=object)

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.stripplot(x='Species',y='sepal length (cm)',data=iris_d,jitter=True,edgecolor='gray',size=8,palette='winter',orient='v')

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxplot(x='Species',y='sepal length (cm)',data=iris_d)
fig=sns.stripplot(x='Species',y= 'sepal length (cm)',data=iris_d,jitter=True,edgecolor='gray')

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxplot(x='Species',y='sepal length (cm)',data=iris_d)
fig=sns.stripplot(x='Species',y= 'sepal length (cm)',data=iris_d,jitter=False,edgecolor='gray')

# %%
ax= sns.boxplot(x="Species", y= "petal length (cm)", data=iris_d)
ax= sns.stripplot(x="Species", y="petal length (cm)", data=iris_d, jitter=True, edgecolor="gray")

boxtwo = ax.artists[2]
boxtwo.set_facecolor('pink')
boxtwo.set_edgecolor('black')
boxthree=ax.artists[1]
boxthree.set_facecolor('red')
boxthree.set_edgecolor('black')
boxthree=ax.artists[0]
boxthree.set_facecolor('green')
boxthree.set_edgecolor('black')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[90], line 4
#       1 ax= sns.boxplot(x="Species", y= "petal length (cm)", data=iris_d)
#       2 ax= sns.stripplot(x="Species", y="petal length (cm)", data=iris_d, jitter=True, edgecolor="gray")
# ----> 4 boxtwo = ax.artists[2]
#       5 boxtwo.set_facecolor('pink')
#       6 boxtwo.set_edgecolor('black')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:1457, in _AxesBase.ArtistList.__getitem__(self, key)
#    1456 def __getitem__(self, key):
# -> 1457     return [artist
#    1458             for artist in self._axes._children
#    1459             if self._type_check(artist)][key]
#
# IndexError: list index out of range

# %%
ax= sns.violinplot(x="Species", y= "petal length (cm)", data=iris_d)

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='Species',y="petal length (cm)",data=iris_d)
plt.subplot(2,2,2)
sns.violinplot(x='Species',y="petal length (cm)",data=iris_d)
plt.subplot(2,2,3)
sns.violinplot(x='Species',y="petal length (cm)",data=iris_d)
plt.subplot(2,2,4)
sns.violinplot(x='Species',y="petal length (cm)",data=iris_d)
# Out:
# <Axes: xlabel='Species', ylabel='petal length (cm)'>

# %%
sns.pairplot(data=iris_d,kind='scatter')

# %%
sns.pairplot(iris_d,hue='Species');

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.heatmap(iris_d.corr(),annot=True,cmap='cubehelix',linewidths=1,linecolor='k',square=True,mask=False, vmin=-1, vmax=1,cbar_kws={"orientation": "vertical"},cbar=True)

# %%
iris_d.hist(edgecolor='black', linewidth=1.2)
fig=plt.gcf()
fig.set_size_inches(12,6)

# %%
sns.set(style="darkgrid")
fig=plt.gcf()
fig.set_size_inches(10,7)
fig = sns.swarmplot(x="Species", y="petal length (cm)", data=iris_d)

# %%
sns.set(style="whitegrid")
fig=plt.gcf()
fig.set_size_inches(10,7)
ax = sns.violinplot(x="Species", y="petal length (cm)", data=iris_d, inner=None)
ax = sns.swarmplot(x="Species", y="petal length (cm)", data=iris_d,color="white", edgecolor="black")

# %%
fig=sns.lmplot(x="petal length (cm)", y="petal width (cm)",data=iris_d)

# %%
sns.FacetGrid(iris_d, hue="Species", height=6) \
   .map(sns.kdeplot, "petal length (cm)") \
   .add_legend()
plt.ioff()

# %%
sns.catplot('Species','sepal length (cm)',data=iris_d)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 sns.catplot('Species','sepal length (cm)',data=iris_d)
#       2 plt.show()
#
# TypeError: catplot() got multiple values for argument 'data'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'iris_d' is your DataFrame containing the iris dataset

sns.catplot('Species', 'sepal length (cm)', data=iris_d)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[109], line 6
#       2 import matplotlib.pyplot as plt
#       4 # Assuming 'iris_d' is your DataFrame containing the iris dataset
# ----> 6 sns.catplot('Species', 'sepal length (cm)', data=iris_d)
#       7 plt.show()
#
# TypeError: catplot() got multiple values for argument 'data'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'iris_d' is your DataFrame containing the iris dataset

sns.factorplot(x='Species', y='sepal length (cm)', data=iris_d)
plt.ioff()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[111], line 6
#       2 import matplotlib.pyplot as plt
#       4 # Assuming 'iris_d' is your DataFrame containing the iris dataset
# ----> 6 sns.factorplot(x='Species', y='sepal length (cm)', data=iris_d)
#       7 plt.ioff()
#       8 plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'factorplot'

# %%
sns.catplot(x='Species', y='sepal length (cm)', data=iris_d)
plt.ioff()
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))

sns.factorplot('Species','sepal length (cm)',data=iris_d,ax=ax[0][0])
sns.factorplot('Species','sepal length (cm)',data=iris_d,ax=ax[0][1])
sns.factorplot('Species','petal length (cm)',data=iris_d,ax=ax[1][0])
sns.factorplot('Species','petal length (cm)',data=iris_d,ax=ax[1][1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[113], line 3
#       1 f,ax=plt.subplots(1,2,figsize=(18,8))
# ----> 3 sns.factorplot('Species','sepal length (cm)',data=iris_d,ax=ax[0][0])
#       4 sns.factorplot('Species','sepal length (cm)',data=iris_d,ax=ax[0][1])
#       5 sns.factorplot('Species','petal length (cm)',data=iris_d,ax=ax[1][0])
#
# AttributeError: module 'seaborn' has no attribute 'factorplot'

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxenplot(x='Species',y='sepal length (cm)',data=iris_d)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'iris_d' is your DataFrame containing the iris dataset

# Create the boxenplot
fig = sns.boxenplot(x='Species', y='sepal length (cm)', data=iris_d)

# Set the size of the figure
fig.set_size_inches(10, 7)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[118], line 10
#       7 fig = sns.boxenplot(x='Species', y='sepal length (cm)', data=iris_d)
#       9 # Set the size of the figure
# ---> 10 fig.set_size_inches(10, 7)
#      12 # Show the plot
#      13 plt.show()
#
# AttributeError: 'Axes' object has no attribute 'set_size_inches'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'iris_d' is your DataFrame containing the iris dataset

# Create the boxenplot
sns.boxenplot(x='Species', y='sepal length (cm)', data=iris_d)

# Set the size of the figure
plt.gcf().set_size_inches(10, 7)

# Show the plot
plt.show()

# %%
sub=iris_d[iris_d['Species']=='Iris-setosa']
sns.kdeplot(data=sub[['sepal length (cm)','sepal width (cm)']],cmap="plasma", shade=True, shade_lowest=False)
plt.title('Iris-setosa')
plt.xlabel('Sepal length cm')
plt.ylabel('Sepal width cm')
# Out:
# Text(0, 0.5, 'Sepal width cm')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'iris_d' is your DataFrame containing the iris dataset

# Filter the data for Iris-setosa
sub = iris[iris['Species'] == 'Iris-setosa']

# Create the KDE plot
sns.kdeplot(data=sub[['sepal length (cm)', 'sepal width (cm)']], cmap="plasma", shade=True, shade_lowest=False)
plt.title('Iris-setosa')
plt.xlabel('sepal length (cm)')
plt.ylabel('sepal width (cm)')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[127], line 7
#       2 import matplotlib.pyplot as plt
#       4 # Assuming 'iris_d' is your DataFrame containing the iris dataset
#       5
#       6 # Filter the data for Iris-setosa
# ----> 7 sub = iris[iris['Species'] == 'Iris-setosa']
#       9 # Create the KDE plot
#      10 sns.kdeplot(data=sub[['sepal length (cm)', 'sepal width (cm)']], cmap="plasma", shade=True, shade_lowest=False)
#
# KeyError: 'Species'

# %%
sns.set_style('darkgrid')
f,axes=plt.subplots(2,2,figsize=(15,15))

k1=sns.boxplot(x="Species", y="petal length (cm)", data=iris_d,ax=axes[0,0])
k2=sns.violinplot(x='Species',y="petal length (cm)",data=iris_d,ax=axes[0,1])
k3=sns.stripplot(x='Species',y='sepal length (cm)',data=iris_d,jitter=True,edgecolor='gray',size=8,palette='winter',orient='v',ax=axes[1,0])
#axes[1,1].hist(iris.hist,bin=10)
axes[1, 1].hist(iris_d['petal length (cm)'], bins=100)
#k2.set(xlim=(-1,0.8))
plt.show()

# %%
iris_d['Species'] = iris_d['Species'].astype('category')
#iris.head()

# %%
list1=list()
mylabels=list()
for gen in iris_d.Species.cat.categories:
    list1.append(iris_d[iris_d['Species'] == gen]['sepal length (cm)'])
    mylabels.append(gen)
    
h=plt.hist(list1,bins=30,stacked=True,rwidth=1,label=mylabels)
plt.legend()
plt.show()

# %%
iris_d.plot.area(y=['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)'],alpha=0.4,figsize=(12, 6));
plt.show()

# %%
sns.distplot(iris_d['sepal length (cm)'],kde=True,bins=20);
plt.show()
