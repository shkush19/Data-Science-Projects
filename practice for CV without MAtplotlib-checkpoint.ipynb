# %%
import cv2

# %%
roseimg=cv2.imread(r'S:\Naresh IT\workshop\roses.jpg')

# %%
type(roseimg)
# Out:
# numpy.ndarray

# %%
cv2.imshow('colorful roses',roseimg)

# %%
cv2.waitKey()
# Out:
# -1

# %% [markdown]
# __Below output with the title--'colorful roses' will appear in new window__
#
# ![image.png](attachment:ac650ac5-8eb6-4f84-bc7e-0b5f805c39c8.png)

# %%
while True:##this loop will not break untill user press the esc key from keyboard
    cv2.imshow('colorful roses',roseimg)

    if cv2.waitKey(1) & 0xFF == 27 :##27 is the ASCII value for escape key
        break

cv2.destroyAllWindows()
