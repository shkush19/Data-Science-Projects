# %%
# !pip install gTTs

# %%
from gtts import gTTS

# %%
from IPython.display import Audio
text_to_speech=gtts('Shree Krishna Govind Hare Murari, Hey Naath Narayan Vasudeva. ')

text_to_speech.save('text_to_speech_gTTs.wav')
sound_file = 'text_to_speech_gTTs.wav'

Audio(sound_file, autoplay= False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 from IPython.display import Audio
# ----> 2 text_to_speech=gtts('Shree Krishna Govind Hare Murari, Hey Naath Narayan Vasudeva. ')
#       4 text_to_speech.save('text_to_speech_gTTs.wav')
#       5 sound_file = 'text_to_speech_gTTs.wav'
#
# NameError: name 'gtts' is not defined

# %%
from gtts import gTTS
from IPython.display import Audio

text_to_speech = gTTS('Shree Krishna Govind Hare Murari, Hey Naath Narayan Vasudeva.')
text_to_speech.save('text_to_speech_gTTs.wav')
sound_file = 'text_to_speech_gTTs.wav'

Audio(sound_file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from gtts import gTTS
from IPython.display import Audio

text_to_speech = gTTS('I love you Navneet ji.')
text_to_speech.save('text_to_speech_gTTs1.wav')
sound_file = 'text_to_speech_gTTs1.wav'

Audio(sound_file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from gtts import gTTS
from IPython.display import Audio

text_to_speech = gTTS('Hello Shikha ki Mummy kaise ho aap, kya kar rhe ho! Ye Aawaz maine AI ke through Banaya hai')
text_to_speech.save('text_to_speech_gTTs2.wav')
sound_file = 'text_to_speech_gTTs2.wav'

Audio(sound_file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from gtts import gTTS
from IPython.display import Audio

text_to_speech = gTTS('Hello Amrita Darling, kya kar rhe ho! Hope tum Jungkuk ke khayalon mein khush hoge! Chinta mat karo Jungkuk tumhe lene South Korea se cycle pe zarur ayega!)
text_to_speech.save('text_to_speech_gTTs3.wav')
sound_file = 'text_to_speech_gTTs3.wav'

Audio(sound_file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
