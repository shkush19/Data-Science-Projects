# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
inc=pd.read_csv(r'S:\Naresh IT\16th April- course review, Stats Introduction\Prakash Sir Work\PROJECT\Inc_Exp_Data.csv')
inc
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              5000              8000                  3             2000
# 1              6000              7000                  2             3000
# 2             10000              4500                  2                0
# 3             10000              2000                  1                0
# 4             12500             12000                  2             3000
# 5             14000              8000                  2                0
# 6             15000             16000                  3            35000
# 7             18000             20000                  5             8000
# 8             19000              9000                  2                0
# 9             20000              9000                  4                0
# 10            20000             18000                  4             8000
# 11            22000             25000                  6            12000
# ...

# %%
inc.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %%
inc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Mthly_HH_Income           50 non-null     int64
#  1   Mthly_HH_Expense          50 non-null     int64
#  2   No_of_Fly_Members         50 non-null     int64
#  3   Emi_or_Rent_Amt           50 non-null     int64
#  4   Annual_HH_Income          50 non-null     int64
#  5   Highest_Qualified_Member  50 non-null     object
#  6   No_of_Earning_Members     50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %%
inc.shape
# Out:
# (50, 7)

# %%
inc.describe().T
# Out:
#                        count       mean            std      min       25%  \
# Mthly_HH_Income         50.0   41558.00   26097.908979   5000.0   23550.0
# Mthly_HH_Expense        50.0   18818.00   12090.216824   2000.0   10000.0
# No_of_Fly_Members       50.0       4.06       1.517382      1.0       3.0
# Emi_or_Rent_Amt         50.0    3060.00    6241.434948      0.0       0.0
# Annual_HH_Income        50.0  490019.04  320135.792123  64200.0  258750.0
# No_of_Earning_Members   50.0       1.46       0.734291      1.0       1.0
#
#                             50%       75%        max
# Mthly_HH_Income         35000.0   50375.0   100000.0
# Mthly_HH_Expense        15500.0   25000.0    50000.0
# No_of_Fly_Members           4.0       5.0        7.0
# Emi_or_Rent_Amt             0.0    3500.0    35000.0
# Annual_HH_Income       447420.0  594720.0  1404000.0
# No_of_Earning_Members       1.0       2.0        4.0

# %%
inc.isna().any()
# Out:
# Mthly_HH_Income             False
# Mthly_HH_Expense            False
# No_of_Fly_Members           False
# Emi_or_Rent_Amt             False
# Annual_HH_Income            False
# Highest_Qualified_Member    False
# No_of_Earning_Members       False
# dtype: bool

# %%
inc.columns
# Out:
# Index(['Mthly_HH_Income', 'Mthly_HH_Expense', 'No_of_Fly_Members',
#        'Emi_or_Rent_Amt', 'Annual_HH_Income', 'Highest_Qualified_Member',
#        'No_of_Earning_Members'],
#       dtype='object')

# %%
inc["Mthly_HH_Income"].mean()
# Out:
# 41558.0

# %%
inc["Mthly_HH_Expense"].median()
# Out:
# 15500.0

# %%
mth_exp_tmp = pd.crosstab(index=inc["Mthly_HH_Expense"], columns="count")
mth_exp_tmp.reset_index(inplace=True)
mth_exp_tmp[mth_exp_tmp['count'] == inc.Mthly_HH_Expense.value_counts().max()]
# Out:
# col_0  Mthly_HH_Expense  count
# 18                25000      8

# %%
colors=('green','red','cyan','orange','pink')
inc['Highest_Qualified_Member'].value_counts().plot(kind="bar",color=colors)
# Out:
# <Axes: >

# %%
inc.plot(x="Mthly_HH_Income", y="Mthly_HH_Expense")
IQR=inc["Mthly_HH_Expense"].quantile(0.75)-inc["Mthly_HH_Expense"].quantile(0.25)
IQR
# Out:
# 15000.0

# %%
inc.plot(x="Mthly_HH_Income", y="Mthly_HH_Expense")
IQR=inc["Mthly_HH_Expense"].quantile(0.90)-inc["Mthly_HH_Expense"].quantile(0.10)
IQR
# Out:
# 32100.0

# %%
pd.DataFrame(inc.iloc[:,0:5].std().to_frame()).T
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0     26097.908979      12090.216824           1.517382      6241.434948
#
#    Annual_HH_Income
# 0     320135.792123

# %%
pd.DataFrame(inc.iloc[:,0:5].var().to_frame()).T
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0     6.811009e+08      1.461733e+08           2.302449     3.895551e+07
#
#    Annual_HH_Income
# 0      1.024869e+11

# %%
inc["Highest_Qualified_Member"].value_counts().to_frame().T
# Out:
#                           Graduate  Under-Graduate  Professional  \
# Highest_Qualified_Member        19              10            10
#
#                           Post-Graduate  Illiterate
# Highest_Qualified_Member              6           5

# %%
colors1=('green','red','cyan','orange','pink')
inc["No_of_Earning_Members"].value_counts().plot(kind="bar",color=colors1)
# Out:
# <Axes: >

# %%
#Here we need to calculate the coeff of variation 

Coeff_of_var_StockA=10/15
print(Coeff_of_var_StockA)
Coeff_of_var_StockB=5/10
print(Coeff_of_var_StockB)
# Out:
# 0.6666666666666666
# 0.5
