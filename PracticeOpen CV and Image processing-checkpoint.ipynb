# %% [markdown]
# __Intro to OpenCV and Image Processing__

# %%
pip install opencv-python #intallation of openCV Library
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as ny
import matplotlib.pyplot as pt
# %matplotlib inline
#importing necessary libraries.

# %%
import cv2##importing necessary computer vision library for image processing

# %%
fluteimg=cv2.imread(r'S:\Naresh IT\workshop\Flute feather.jpg')##loading image

# %%
type(fluteimg)##checking type of image
# Out:
# numpy.ndarray

# %%
fluteimg.shape#fetching dimensions of an array
# Out:
# (316, 312, 3)

# %%
pt.imshow(fluteimg)#Image visualize

# %%
fluteimg#Shows the array dimension of image array
# Out:
# array([[[ 71,  64,  15],
#         [ 72,  65,  16],
#         [ 71,  64,  15],
#         ...,
#         [163, 174, 148],
#         [164, 175, 149],
#         [164, 175, 149]],
#
#        [[ 82,  75,  26],
#         [ 81,  74,  25],
#         [ 78,  71,  22],
#         ...,
#         [163, 174, 148],
#         [164, 175, 149],
#         [164, 175, 149]],
#
#        [[ 90,  83,  34],
#         [ 90,  83,  34],
#         [ 87,  80,  31],
#         ...,
#         [164, 175, 149],
#         [165, 176, 150],
#         [165, 176, 150]],
#
#        ...,
#
#        [[ 25,  36,  28],
#         [ 24,  35,  27],
#         [ 24,  35,  27],
#         ...,
#         [ 72, 103, 118],
#         [ 72, 103, 118],
#         [ 69, 100, 115]],
#
#        [[ 28,  36,  29],
#         [ 27,  35,  28],
#         [ 27,  35,  28],
#         ...,
#         [ 68, 101, 117],
#         [ 68, 101, 117],
#         [ 64,  97, 113]],
#
#        [[ 28,  36,  29],
#         [ 28,  36,  29],
#         [ 28,  36,  29],
# ...

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)#it's converting the image from the BGR (Blue-Green-Red) color space to the RGB (Red-Green-Blue) color space.

# %%
pt.imshow(fix_img)#visualize image

# %%
fluteimg_grey=cv2.imread(r'S:\Naresh IT\workshop\Flute feather.jpg',cv2.IMREAD_GRAYSCALE)##loading image in grey scale

# %%
fluteimg_grey##fetch image array dimensions
# Out:
# array([[ 50,  51,  50, ..., 165, 166, 166],
#        [ 61,  60,  57, ..., 165, 166, 166],
#        [ 69,  69,  66, ..., 166, 167, 167],
#        ...,
#        [ 32,  31,  31, ..., 104, 104, 101],
#        [ 33,  32,  32, ..., 102, 102,  98],
#        [ 33,  33,  33, ..., 101, 100,  95]], dtype=uint8)

# %%
pt.imshow(fluteimg_grey)#visualize image

# %%
fluteimg_grey.shape#shows the dimensions of picture array
# Out:
# (316, 312)

# %%
fluteimg_grey.min()
# Out:
# 0

# %%
fluteimg_grey.max()
# Out:
# 255

# %%
pt.imshow(fluteimg_grey, cmap = 'gray')##To get image in grayscale

# %%
pt.imshow(fluteimg_grey, cmap = 'magma')

# %%
pt.imshow(fluteimg_grey, cmap = 'Accent')

# %%
pt.imshow(fix_img)

# %%
pt.imshow(fluteimg)

# %%
fix_img.shape
# Out:
# (316, 312, 3)

# %%
fix_img_1 = cv2.resize(fix_img,(500,367))

# %%
fix_img_1.shape
# Out:
# (367, 500, 3)

# %%
w_ratio = 0.5
h_ratio = 0.5
##manually setting heigth and width

# %%
fix_img_2 = cv2.resize(fix_img,(0,0), fix_img, w_ratio, h_ratio)

# %%
fix_img_2
# Out:
# array([[[ 21,  70,  77],
#         [ 19,  68,  75],
#         [ 34,  82,  92],
#         ...,
#         [148, 174, 163],
#         [148, 174, 163],
#         [149, 175, 164]],
#
#        [[ 35,  84,  91],
#         [ 32,  81,  88],
#         [ 34,  82,  92],
#         ...,
#         [149, 175, 164],
#         [149, 175, 164],
#         [151, 177, 166]],
#
#        [[ 33,  82,  89],
#         [ 35,  84,  91],
#         [ 36,  84,  94],
#         ...,
#         [149, 175, 162],
#         [150, 176, 163],
#         [153, 179, 166]],
#
#        ...,
#
#        [[ 23,  31,  20],
#         [ 23,  31,  20],
#         [ 23,  31,  21],
#         ...,
#         [118, 104,  75],
#         [113,  99,  70],
#         [111,  97,  68]],
#
#        [[ 27,  35,  24],
#         [ 26,  34,  23],
#         [ 25,  33,  23],
#         ...,
#         [116, 101,  70],
#         [117, 102,  71],
#         [118, 103,  72]],
#
#        [[ 29,  36,  28],
#         [ 29,  36,  28],
#         [ 28,  35,  28],
# ...

# %%
pt.imshow(fix_img_2)

# %%
flpimage = cv2.flip(fix_img_2,0)
pt.imshow(flpimage)

# %%
flpimage = cv2.flip(fix_img_2,1)
pt.imshow(flpimage)

# %%
img3 = cv2.flip(fix_img_2, 3)
pt.imshow(img3)

# %%
# To save your new image into your desired folder
output_folder = 'S:\\Naresh IT\\workshop'  # Replace this with the path to your desired folder
output_filename = 'new_genai_flutefeather.jpg'

# Combine the folder path and filename to get the full output path
output_path = output_folder + output_filename

# Write the image to the specified path
cv2.imwrite(output_path, img3)
# Out:
# True

# %%
pwd
# Out:
# 'C:\\Users\\hp'
