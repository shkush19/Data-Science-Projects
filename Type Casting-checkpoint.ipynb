# %% [markdown]
# ✍Words are called 'Tokens' in python For example:---
# ✍"My name is Shikha"-----Here, this statement has 4 words and these words are called tokens.
#
# ✍In Chat GPT 3.5----limited to 1500 tokens.
# if you upgrade Chat GPT 3.5 to 4.0----token limit increased to 2500.
#
# ✍2 types of Indexing--Forward Indexing and Backward indexing
# Forward indexing starts with 0 and the direction is Left to right, whereas, Backward indexing starts with -1 and the direction is right to left.
#
# ########Unable to add Image#######
#
# ✍we use print() to print multiple values at a time.
#
# ✍if you took multiple variables and assign some values to it and if you print without print function then you get the last variable's value whatever you assign.
#
# ✍Also, if you use type() and pass the arguement with print() by passing variable to it then it will return the value assigned to the variable not the type of the variable along with NoneType, Example will be available in below notes.
#
# 👇Let's understand Data types with Type Casting.

# %% [markdown]
# ![Index-in-Python-1024x508.png](attachment:Index-in-Python-1024x508.png)

# %%
import sys
import keyword
import operator

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ## For multiline Comments--- we should learn this concept because when we deals with NLP (Natural Language Processing) we deals with text and multiline statement, so there we use such concepts.

# %%
'Working with
   best software industry'   ## will give an error
# Out:
#   Cell In[4], line 1
#     'Working with
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'''Working with 
      best software industry''' ## will not show error as three inverted commas is for printing multiline comments
# Out:
# 'Working with \n      best software industry'

# %%
string_4= ('Lily ' 
          'pansy '
          'marrigold '
          'rose '
          'dahilia')  
print(string_4)
# Out:
# Lily pansy marrigold rose dahilia

# %%
string_6= 'shikha '
string_6= string_6*10
string_6
# Out:
# 'shikha shikha shikha shikha shikha shikha shikha shikha shikha shikha '

# %%
len(string_6)
# Out:
# 70

# %% [markdown]
# # Let's learn Forward and Backward indexing concepts

# %%
string_10 = 'Lets have fun with Python'
string_10
# Out:
# 'Lets have fun with Python'

# %%
string_10[0]
# Out:
# 'L'

# %%
string_10[10] ##  because it runs on the concept of n-1 ---Forward Indexing
# Out:
# 'f'

# %%
string_10[5:9] ## will print <space> till letter 'v'----Forward Indexing--Also, :colon works in n-1 concept.
# Out:
# 'have'

# %%
string_10[-4] # will print from Right to Left
# Out:
# 't'

# %%
string_10
# Out:
# 'Lets have fun with Python'

# %%
string_10[-5:-1] #print reverse from 'n' to 't',,,, Here, starting index should be less than to the ending index if you print 
                   #reverse---Example-- -5 is less than -1
# Out:
# 'ytho'

# %% [markdown]
# # Let's understand some facts about Complex Data Types.

# %%
comp = 9+2j
comp
# Out:
# (9+2j)

# %%
type(comp)
# Out:
# complex

# %%
print(type(comp))
# Out:
# <class 'complex'>

# %%
id(comp)
# Out:
# 1951372703312

# %%
len(comp) ### complex data type has no length.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 len(comp)
#
# TypeError: object of type 'complex' has no len()

# %%
comp.conjugate ###
# Out:
# <function complex.conjugate()>

# %%
comp.imag
# Out:
# 2.0

# %%
comp.real
# Out:
# 9.0

# %% [markdown]
# ### Let's deal with Integer value

# %%
int(6666.90)
# Out:
# 6666

# %%
int(99.55.33) ## cannot pass value which has 3 dots.
# Out:
#   Cell In[53], line 1
#     int(99.55.33)
#         ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ## Let's introduce boolean to int with And, Or operators

# %%
int(True) and int(True)
# Out:
# 1

# %%
int(False) and int(False)
# Out:
# 0

# %%
int(False) and int(True)
# Out:
# 0

# %%
int(True) and int(False)
# Out:
# 0

# %%
int(True) or int(True)
# Out:
# 1

# %%
int(False) or int(False)
# Out:
# 0

# %%
int(False) or int(True)
# Out:
# 1

# %%
int(True) or int(False)
# Out:
# 1

# %%
int("30")  ## will work coz, at last we pass numbers as an argument.
# Out:
# 30

# %%
int("Thirty")  ## will not work coz, at last we are passing string as an argument.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 int("Thirty")
#
# ValueError: invalid literal for int() with base 10: 'Thirty'

# %% [markdown]
# #### understanding Int Type casting with Boolean Datatype combining Exception Handling along with '<' operator

# %%
x = "shikha"
y = int(False)
try:
    if x<y:
        print("Oops not a valid one") 
except:
    print("Please enter valid inputs")
finally:
    print("Code Executed")
# Out:
# Please enter valid inputs
# Code Executed

# %%
x = 78
y = 56
try:
    if x<y:
        print("Oops not a valid one") 
    else:
        print("Valid")
except:
    print("Please enter valid inputs")
finally:
    print("Code Executed")
# Out:
# Valid
# Code Executed

# %%
x = int(True)
y = int(False)
try:
    if x<y:
        print("Oops not a valid one") 
    else:
        print("Valid")
except:
    print("Please enter valid inputs")
finally:
    print("Code Executed")
# Out:
# Valid
# Code Executed

# %%
x = int(False)
y = int(True)
try:
    if x<y:
        print("Oops not a valid one") 
    else:
        print("Valid")
except:
    print("Please enter valid inputs")
finally:
    print("Code Executed")
# Out:
# Oops not a valid one
# Code Executed

# %%
x = int(True)
y = int(False)
try:
    if x<y:
        print("Oops not a valid one", x) 
    else:
        print("Valid", y)
except:
    print("Please enter valid inputs")
finally:
    print("Code Executed")
    
## In this the value of "False" will print because we use 'x' along with print statement.
# Out:
# Valid 0
# Code Executed

# %%
x = int(True)
y = float(False)
try:
    if x<y:
        print("Oops not a valid one", x) 
    else:
        print("Valid", y)
except:
    print("Please enter valid inputs")
finally:
    print("Code Executed")
    
### In this code the value 0.0 is printing because we assigned Float value to the 'y'
# Out:
# Valid 0.0
# Code Executed

# %% [markdown]
# # Let's revise little bit Data types again

# %%
val1 = 13
val2 = 12
print(val1)
print(val2)
# Out:
# 13
# 12

# %%
type(print(val1))
# Out:
# 13
# NoneType

# %%
type(val1)
# Out:
# int

# %%
print(type(val1))
# Out:
# <class 'int'>

# %% [markdown]
# ##### if you use type() and pass the arguement with print() by passing variable to it then it will always return the value assigned to the variable not the type of the variable along with NoneType

# %%
type(print(val1))
# Out:
# 13
# NoneType

# %%
id(val1)  ##shows the address of the Val1
# Out:
# 140703279977640

# %%
## suppose if you take some variables and assign same values such as --###
val1 = 13
val2 = 13
print(id(val1))
print(id(val2))

## this will give you the same address, coz Python has a feature called Memory Management as it saves the space.
## In this example 2 variables pointing to the same address and that's where it is saving the space.
## In system or in python "Constructor" assigns the memory space to the values of the variables.
# Out:
# 140703279977640
# 140703279977640

# %%
int("Excellent Python") ## Error because we cannot pass string as a value if we pass string as an arguement.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 int("Excellent Python")
#
# ValueError: invalid literal for int() with base 10: 'Excellent Python'

# %%
int(5+19j) ##Error because we cannot pass Complex as a value if we pass complex as an arguement.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 int(5+19j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %% [markdown]
# #### Let's deal with Float Datatypes.

# %%
float(50)
# Out:
# 50.0

# %%
float(True)
# Out:
# 1.0

# %%
float(1+9j)  ##Float will not accept complex Values as an arguement.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 float(1+9j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('400') ## will work coz, at last we pass numbers as an argument.
# Out:
# 400.0

# %%
float("Four Hundred") ## will not work coz, at last we are passing string as an argument.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 float("Four Hundred")
#
# ValueError: could not convert string to float: 'Four Hundred'

# %% [markdown]
# ## Let's introduce boolean to Float with And, Or operators

# %%
float(True) and float(True)
# Out:
# 1.0

# %%
float(True) and float(False)
# Out:
# 0.0

# %%
float(False) and float(True)
# Out:
# 0.0

# %%
float(False) and float(False)
# Out:
# 0.0

# %%
float(True) or float(True)
# Out:
# 1.0

# %%
float(True) or float(False)
# Out:
# 1.0

# %%
float(False) or float(True)
# Out:
# 1.0

# %%
float(False) or float(False)
# Out:
# 0.0

# %% [markdown]
# #### understanding Float Type casting with Boolean Datatype combining Exception Handling along with "!=" and logical operators

# %%
N = float(False)
Y = float(True)
try:
    if N != Y:
        print("Not equal to", N , Y)
    else:
        print("Equal to", N , Y)
except:
    print("Enter Valid inputs")
finally:
    print("Code is running perfectly")
# Out:
# Not equal to 0.0 1.0
# Code is running perfectly

# %%
N = float(True)
Y = float(True)
try:
    if N != Y:
        print("Not equal to", N , Y)
    else:
        print("Equal to", N , Y)
except:
    print("Enter Valid inputs")
finally:
    print("Code is running perfectly")
# Out:
# Equal to 1.0 1.0
# Code is running perfectly

# %%
N = float(True)
Y = float(True)
B = float(False)
U = float(True)
try:
    if N != Y and B <= U:
        print("Not equal to", N , Y , B , U)
    else:
        print("Equal to", N , Y , B , U)
except:
    print("Enter Valid inputs")
finally:
    print("Code is running perfectly")
# Out:
# Equal to 1.0 1.0 0.0 1.0
# Code is running perfectly

# %%
N = float(True)
Y = float(False)
B = float(True)
U = float(False)
try:
    if N != Y and B <= U:
        print("Not equal to", N , Y , B , U)
    else:
        print("Equal to", N , Y , B , U)
except:
    print("Enter Valid inputs")
finally:
    print("Code is running perfectly")
# Out:
# Equal to 1.0 0.0 1.0 0.0
# Code is running perfectly

# %%
N = float(True)
Y = float(False)
B = float(True)
U = float(False)
try:
    if N != Y or B <= U:
        print("Not equal to", N , Y , B , U)
    else:
        print("Equal to", N , Y , B , U)
except:
    print("Enter Valid inputs")
finally:
    print("Code is running perfectly")
# Out:
# Not equal to 1.0 0.0 1.0 0.0
# Code is running perfectly

# %% [markdown]
# #### understanding Complex Type casting with Boolean, Float, Integer and string Datatype combining Exception Handling along with '>', '==', 'and' and 'or' operator

# %%
com = 8+4j
com1 = 3+2j
print(com)
print(com1)
# Out:
# (8+4j)
# (3+2j)

# %%
com = 8+4j
com1 = 3+2j
com
com1
# Out:
# (3+2j)

# %%
com = 8+4j ## by default it is returning float values.
com.real
# Out:
# 8.0

# %%
int(com.real)
# Out:
# 8

# %%
int(com.imag)
# Out:
# 4

# %%
com = 8+4j
com1 = 3+2j

try:
    if com.real > com1.real:
        print("Greater number", int(com.real))
    else:
        print("Smaller number", int(com1.real))
except:
    ("print done")
finally:
    ("Code has been executed")
# Out:
# Greater number 8

# %%
com = 8+4j
com1 = 3+2j

try:
    if com.real < com1.imag:
        print("Greater number", int(com.real))
    else:
        print("Smaller number", int(com1.real))
except:
    ("print done")
finally:
    ("Code has been executed")
# Out:
# Smaller number 3

# %%
com = 8+4j
com1 = 3+2j

try:
    if com.imag == com1.imag:
        print("Greater number", int(com.imag))
    else:
        print("Smaller number", int(com1.imag))
except:
    ("print done")
finally:
    ("Code has been executed")
# Out:
# Smaller number 2

# %%
com = "Mahadev"
com1 = 3+2j

try:
    if com & com1:
        print("Greater number", com)
    else:
        print("Smaller number", com1)
except:
    print("done")
finally:
    print("Code has been executed")
    
## Why except will print because try block has an error , as "&" symbol used.
# Out:
# done
# Code has been executed

# %% [markdown]
# ## let's jump to basic of complex again to understand better.

# %%
complex(10,4)
# Out:
# (10+4j)

# %%
complex('eleven', 4) ## Complex cannot work with Strings.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 complex('eleven', 4)
#
# TypeError: complex() can't take second arg if first is a string

# %% [markdown]
# ## let's understand string better

# %%
str(3.9)
# Out:
# '3.9'

# %%
str('twelve')
# Out:
# 'twelve'

# %%
str(twelve) ## cannot pass string as an arguement without commas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 str(twelve)
#
# NameError: name 'twelve' is not defined

# %%
str(2+7j)
# Out:
# '(2+7j)'

# %% [markdown]
# ### understanding string with basic swapping Program by combining Exception Handling

# %%
string_1 = 'amrita'
string_2 = 'Singh'
string_3 = string_2 , string_1
string_3

try:
    if string_3 == string_2:
        print("matched")
    else:
        print("not matched")
except:
    print("Error in code")
finally:
    print("Swapped", string_3)
# Out:
# not matched
# Swapped ('Singh', 'amrita')

# %% [markdown]
# ## understanding Boolean with logical operators by combining Exception Handling

# %%
bool(True)
# Out:
# True

# %%
bool(False)
# Out:
# False

# %%
w = 56
q = 87

w > q & q == w
# Out:
# False

# %%
w = 56
q = 87

try:
    if q != w & w <= q:
        print("Not equal to")
    else:
        print("Equal to")
except:
    print("Enter Valid inputs")
finally:
    print("Code is running perfectly")
# Out:
# Not equal to
# Code is running perfectly
