# %%
import pandas as pa ##importing libraries

# %%
raw = pa.read_excel(r'S:\Naresh IT\3rd MArch - Eda practicle\Self learning\Raw Data.xlsx')
raw
##Reading dataset
# Out:
#          Site      Department   Location Rawmaterial  Production   Year
# 0  Plati>>num          Mining  Hyde%rbad   1 Unit'''    200000.0  20<09
# 1     Diamond   Manufacturing      Delhi    20 u{nit    500000.0   2010
# 2        Gold  Engi***neering        NaN         NaN    450000.0  20<11
# 3     Silv'er           Sales       Pune     55 unit         NaN   2012
# 4      Bronze       Marketing      Delhi     60 unit    230000.0   2013
# 5      Copper   Manufacturing         MP     43 unit    260000.0  2014/
# 6        Gini   Manufacturing        NaN         NaN    200000.0   2017

# %%
raw.columns ##fetching columns
# Out:
# Index(['Site', 'Department', 'Location', 'Rawmaterial', 'Production', 'Year'], dtype='object')

# %%
raw.shape ##fetching no. of rows and columns
# Out:
# (7, 6)

# %%
raw.head() ##top 5 rows
# Out:
#          Site      Department   Location Rawmaterial  Production   Year
# 0  Plati>>num          Mining  Hyde%rbad   1 Unit'''    200000.0  20<09
# 1     Diamond   Manufacturing      Delhi    20 u{nit    500000.0   2010
# 2        Gold  Engi***neering        NaN         NaN    450000.0  20<11
# 3     Silv'er           Sales       Pune     55 unit         NaN   2012
# 4      Bronze       Marketing      Delhi     60 unit    230000.0   2013

# %%
raw.tail() ##bottom 5 rows
# Out:
#       Site      Department Location Rawmaterial  Production   Year
# 2     Gold  Engi***neering      NaN         NaN    450000.0  20<11
# 3  Silv'er           Sales     Pune     55 unit         NaN   2012
# 4   Bronze       Marketing    Delhi     60 unit    230000.0   2013
# 5   Copper   Manufacturing       MP     43 unit    260000.0  2014/
# 6     Gini   Manufacturing      NaN         NaN    200000.0   2017

# %%
raw.tail(3) ##bottom 3 rows
# Out:
#      Site     Department Location Rawmaterial  Production   Year
# 4  Bronze      Marketing    Delhi     60 unit    230000.0   2013
# 5  Copper  Manufacturing       MP     43 unit    260000.0  2014/
# 6    Gini  Manufacturing      NaN         NaN    200000.0   2017

# %%
raw.info() ##displays the information of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Site         7 non-null      object
#  1   Department   7 non-null      object
#  2   Location     5 non-null      object
#  3   Rawmaterial  5 non-null      object
#  4   Production   6 non-null      float64
#  5   Year         7 non-null      object
# dtypes: float64(1), object(5)
# memory usage: 468.0+ bytes

# %%
raw ##fetching the raw dataset
# Out:
#          Site      Department   Location Rawmaterial  Production   Year
# 0  Plati>>num          Mining  Hyde%rbad   1 Unit'''    200000.0  20<09
# 1     Diamond   Manufacturing      Delhi    20 u{nit    500000.0   2010
# 2        Gold  Engi***neering        NaN         NaN    450000.0  20<11
# 3     Silv'er           Sales       Pune     55 unit         NaN   2012
# 4      Bronze       Marketing      Delhi     60 unit    230000.0   2013
# 5      Copper   Manufacturing         MP     43 unit    260000.0  2014/
# 6        Gini   Manufacturing        NaN         NaN    200000.0   2017

# %%
raw['Site']##1st column of dataset
# Out:
# 0    Plati>>num
# 1       Diamond
# 2          Gold
# 3       Silv'er
# 4        Bronze
# 5        Copper
# 6          Gini
# Name: Site, dtype: object

# %%
raw.isnull()##searching null values
# Out:
#     Site  Department  Location  Rawmaterial  Production   Year
# 0  False       False     False        False       False  False
# 1  False       False     False        False       False  False
# 2  False       False      True         True       False  False
# 3  False       False     False        False        True  False
# 4  False       False     False        False       False  False
# 5  False       False     False        False       False  False
# 6  False       False      True         True       False  False

# %%
raw.isnull().sum() ##displays count of null values in the dataset
# Out:
# Site           0
# Department     0
# Location       2
# Rawmaterial    2
# Production     1
# Year           0
# dtype: int64

# %%
##Cleaning the data column by column 

raw['Site']
# Out:
# 0    Plati>>num
# 1       Diamond
# 2          Gold
# 3       Silv'er
# 4        Bronze
# 5        Copper
# 6          Gini
# Name: Site, dtype: object

# %%
raw['Site'] = raw['Site'].str.replace(r'\W','', regex = True)

# %%
raw['Site']
# Out:
# 0    Platinum
# 1     Diamond
# 2        Gold
# 3      Silver
# 4      Bronze
# 5      Copper
# 6        Gini
# Name: Site, dtype: object

# %%
raw
# Out:
#        Site      Department   Location Rawmaterial  Production   Year
# 0  Platinum          Mining  Hyde%rbad   1 Unit'''    200000.0  20<09
# 1   Diamond   Manufacturing      Delhi    20 u{nit    500000.0   2010
# 2      Gold  Engi***neering        NaN         NaN    450000.0  20<11
# 3    Silver           Sales       Pune     55 unit         NaN   2012
# 4    Bronze       Marketing      Delhi     60 unit    230000.0   2013
# 5    Copper   Manufacturing         MP     43 unit    260000.0  2014/
# 6      Gini   Manufacturing        NaN         NaN    200000.0   2017

# %%
raw['Location'] = raw['Location'].str.replace(r'\W','',regex=True)

# %%
raw
# Out:
#        Site      Department  Location Rawmaterial  Production   Year
# 0  Platinum          Mining  Hyderbad   1 Unit'''    200000.0  20<09
# 1   Diamond   Manufacturing     Delhi    20 u{nit    500000.0   2010
# 2      Gold  Engi***neering       NaN         NaN    450000.0  20<11
# 3    Silver           Sales      Pune     55 unit         NaN   2012
# 4    Bronze       Marketing     Delhi     60 unit    230000.0   2013
# 5    Copper   Manufacturing        MP     43 unit    260000.0  2014/
# 6      Gini   Manufacturing       NaN         NaN    200000.0   2017

# %%
raw['Rawmaterial']=raw['Rawmaterial'].str.extract('(\d+)')

# %%
raw
# Out:
#        Site      Department  Location Rawmaterial  Production   Year
# 0  Platinum          Mining  Hyderbad           1    200000.0  20<09
# 1   Diamond   Manufacturing     Delhi          20    500000.0   2010
# 2      Gold  Engi***neering       NaN         NaN    450000.0  20<11
# 3    Silver           Sales      Pune          55         NaN   2012
# 4    Bronze       Marketing     Delhi          60    230000.0   2013
# 5    Copper   Manufacturing        MP          43    260000.0  2014/
# 6      Gini   Manufacturing       NaN         NaN    200000.0   2017

# %%
raw['Year']=raw['Year'].str.extract('(\d+)') ## not working

# %%
raw
# Out:
#        Site      Department  Location Rawmaterial  Production  Year
# 0  Platinum          Mining  Hyderbad           1    200000.0    20
# 1   Diamond   Manufacturing     Delhi          20    500000.0   NaN
# 2      Gold  Engi***neering       NaN         NaN    450000.0    20
# 3    Silver           Sales      Pune          55         NaN   NaN
# 4    Bronze       Marketing     Delhi          60    230000.0   NaN
# 5    Copper   Manufacturing        MP          43    260000.0  2014
# 6      Gini   Manufacturing       NaN         NaN    200000.0   NaN
