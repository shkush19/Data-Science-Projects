# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
sns.set(style="whitegrid")
import matplotlib.pyplot as plt
from collections import Counter
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
fi=pd.read_csv(r'S:\Naresh IT\5th April- Seaborn, Eda practicle, python\Prakash Sir Work\Seaborn - SPORT\FIFA.csv')
fi
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
fi.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
fi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
fi['Body Type'].value_counts()
# Out:
# Normal                 10595
# Lean                    6417
# Stocky                  1140
# Messi                      1
# C. Ronaldo                 1
# Neymar                     1
# Courtois                   1
# PLAYER_BODY_TYPE_25        1
# Shaqiri                    1
# Akinfenwa                  1
# Name: Body Type, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8,6))
x = fi['Age']
ax = sns.distplot(x, bins=10)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
x = fi['Age']
x = pd.Series(x, name="Age variable")
ax = sns.distplot(x, bins=10)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
x = fi['Age']
ax = sns.distplot(x, bins=10, vertical = True)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
x = fi['Age']
x = pd.Series(x, name="Age variable")
ax = sns.kdeplot(x)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
x = fi['Age']
x = pd.Series(x, name="Age variable")
ax = sns.kdeplot(x, shade=True, color='g')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
x = fi['Age']
ax = sns.distplot(x, kde=False, rug=True, bins=10)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
x = fi['Age']
ax = sns.distplot(x, hist=False, rug=True, bins=10)
plt.show()

# %%
fi['Preferred Foot'].nunique()
# Out:
# 2

# %%
fi['Preferred Foot'].value_counts()
# Out:
# Right    13948
# Left      4211
# Name: Preferred Foot, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.countplot(x="Preferred Foot", data=fi, color="g")
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.countplot(x="Preferred Foot", hue="Real Face", data=fi)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.countplot(y="Preferred Foot", data=fi, color="r")
plt.show()

# %%
g = sns.catplot(x="Preferred Foot", kind="count", palette="ch:.25", data=fi)

# %%
fi['International Reputation'].nunique()
# Out:
# 5

# %%
fi['International Reputation'].value_counts()
# Out:
# 1.0    16532
# 2.0     1261
# 3.0      309
# 4.0       51
# 5.0        6
# Name: International Reputation, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="International Reputation", y="Potential", data=fi)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="International Reputation", y="Potential", data=fi, jitter=0.01)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="International Reputation", y="Potential", hue="Preferred Foot", 
                   data=fi, jitter=0.2, palette="Set1", dodge=True)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="International Reputation", y="Potential", hue="Preferred Foot", 
                   data=fi, palette="Set3", size=20, marker="D",
                   edgecolor="gray", alpha=.25)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=fi["Potential"])
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x="International Reputation", y="Potential", data=fi)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x="International Reputation", y="Potential", hue="Preferred Foot", data=fi, palette="Set2")
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.violinplot(x=fi["Potential"])
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.violinplot(x="International Reputation", y="Potential", data=fi)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.violinplot(x="International Reputation", y="Potential", hue="Preferred Foot", data=fi, palette="muted")
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.violinplot(x="International Reputation", y="Potential", hue="Preferred Foot", 
               data=fi, palette="muted", split=True)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.pointplot(x="International Reputation", y="Potential", data=fi)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.pointplot(x="International Reputation", y="Potential", hue="Preferred Foot", data=fi)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.pointplot(x="International Reputation", y="Potential", hue="Preferred Foot", data=fi, dodge=True)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.pointplot(x="International Reputation", y="Potential", hue="Preferred Foot", 
              data=fi, markers=["o", "x"], linestyles=[":", "-"])
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", data=fi)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", hue="Preferred Foot", data=fi)
plt.show()

# %%
from numpy import median
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", data=fi, estimator=median)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", data=fi, ci=68)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", data=fi, ci="sd")
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", data=fi, capsize=0.2)
plt.show()

# %%
g = sns.relplot(x="Overall", y="Potential", data=fi)

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.scatterplot(x="Height", y="Weight", data=fi)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.lineplot(x="Stamina", y="Strength", data=fi)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.regplot(x="Overall", y="Potential", data=fi)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.regplot(x="Overall", y="Potential", data=fi, color= "r", marker="+")
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.regplot(x="International Reputation", y="Potential", data=fi, x_jitter=.01)
plt.show()

# %%
g= sns.lmplot(x="Overall", y="Potential", data=fi)

# %%
g= sns.lmplot(x="Overall", y="Potential", hue="Preferred Foot", data=fi)

# %%
g= sns.lmplot(x="Overall", y="Potential", hue="Preferred Foot", data=fi, palette="Set2")

# %%
g= sns.lmplot(x="Overall", y="Potential", col="Preferred Foot", data=fi)

# %%
g = sns.FacetGrid(fi, col="Preferred Foot")

# %%
g = sns.FacetGrid(fi, col="Preferred Foot")
g = g.map(plt.hist, "Potential")

# %%
g = sns.FacetGrid(fi, col="Preferred Foot")
g = g.map(plt.hist, "Potential", bins=10, color="g")

# %%
g = sns.FacetGrid(fi, col="Preferred Foot")
g = (g.map(plt.scatter, "Height", "Weight", edgecolor="g").add_legend())

# %%
g = sns.FacetGrid(fi, col="Preferred Foot", height=5, aspect=1)
g = g.map(plt.hist, "Potential")

# %%
fi_new = fi[['Age', 'Potential', 'Strength', 'Stamina', 'Preferred Foot']]
fi_new
# Out:
#        Age  Potential  Strength  Stamina Preferred Foot
# 0       31         94      59.0     72.0           Left
# 1       33         94      79.0     88.0          Right
# 2       26         93      49.0     81.0          Right
# 3       27         93      64.0     43.0          Right
# 4       27         92      75.0     90.0          Right
# ...    ...        ...       ...      ...            ...
# 18202   19         65      47.0     40.0          Right
# 18203   19         63      67.0     43.0          Right
# 18204   16         67      32.0     55.0          Right
# 18205   17         66      48.0     40.0          Right
# 18206   16         66      60.0     47.0          Right
#
# [18207 rows x 5 columns]

# %%
g = sns.PairGrid(fi_new)
g = g.map(plt.scatter)

# %%
g = sns.PairGrid(fi_new)
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)

# %%
g = sns.PairGrid(fi_new, hue="Preferred Foot")
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)
g = g.add_legend()

# %%
g = sns.PairGrid(fi_new, hue="Preferred Foot")
g = g.map_diag(plt.hist, histtype="step", linewidth=3)
g = g.map_offdiag(plt.scatter)
g = g.add_legend()

# %%
g = sns.PairGrid(fi_new, vars=['Age', 'Stamina'])
g = g.map(plt.scatter)
