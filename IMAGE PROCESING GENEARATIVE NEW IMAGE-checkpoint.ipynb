# %% [markdown]
# # INTRODUCTION TO OPENCV & IMAGE PROCESSING

# %%
#pip install opencv-python

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread(r'C:\Users\A3MAX SOFTWARE TECH\Desktop\WORK\1. KODI WORK\1. NARESH\10. WORKSHOP\8. Exploring Generative AI through computer vision\elephant 1.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1000, 735, 3)

# %%
plt.imshow(img)

# %%
img
# Out:
# array([[[  3,  52,  30],
#         [  5,  54,  32],
#         [  5,  54,  32],
#         ...,
#         [  9,  95,  61],
#         [ 13,  99,  65],
#         [  8,  94,  60]],
#
#        [[  5,  54,  32],
#         [  6,  55,  33],
#         [  6,  55,  33],
#         ...,
#         [  2,  89,  55],
#         [  5,  92,  58],
#         [  8,  95,  61]],
#
#        [[  5,  54,  34],
#         [  6,  55,  35],
#         [  7,  53,  34],
#         ...,
#         [  1,  93,  58],
#         [  0,  90,  55],
#         [  2,  94,  59]],
#
#        ...,
#
#        [[ 61,  83,  89],
#         [ 60,  82,  88],
#         [ 55,  77,  83],
#         ...,
#         [ 38,  80,  79],
#         [ 20,  62,  61],
#         [ 11,  53,  52]],
#
#        [[ 54,  73,  81],
#         [ 53,  72,  80],
#         [ 44,  63,  71],
#         ...,
#         [ 63, 101, 103],
#         [ 68, 106, 108],
#         [ 72, 107, 110]],
#
#        [[ 57,  74,  83],
#         [ 52,  69,  78],
#         [ 32,  49,  58],
# ...

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread(r'C:\Users\A3MAX SOFTWARE TECH\Desktop\WORK\1. KODI WORK\1. NARESH\10. WORKSHOP\8. Exploring Generative AI through computer vision\elephant 1.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1000, 735)

# %%
img_gray
# Out:
# array([[ 40,  42,  42, ...,  75,  79,  74],
#        [ 42,  43,  43, ...,  69,  72,  75],
#        [ 42,  43,  42, ...,  72,  69,  73],
#        ...,
#        [ 82,  81,  76, ...,  75,  57,  48],
#        [ 73,  72,  63, ...,  97, 102, 104],
#        [ 75,  70,  50, ..., 114, 116, 125]], dtype=uint8)

# %%
img_gray.min()
# Out:
# 0

# %%
img_gray.max()
# Out:
# 255

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap = 'gray')

# %%
plt.imshow(img_gray, cmap = 'magma')

# %%
plt.imshow(img_gray, cmap = 'Accent')

# %%
plt.imshow(img)

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (1000, 735, 3)

# %%
fix_img_1 = cv2.resize(fix_img,(500,367))

# %%
fix_img_1.shape
# Out:
# (367, 500, 3)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
fix_img_2 = cv2.resize(fix_img,(0,0), fix_img, w_ratio, h_ratio)

# %%
fix_img_2
# Out:
# array([[[ 32,  54,   5],
#         [ 31,  53,   5],
#         [ 23,  45,   1],
#         ...,
#         [ 59,  93,   5],
#         [ 60,  94,   7],
#         [ 60,  94,   8]],
#
#        [[ 34,  54,   5],
#         [ 31,  50,   4],
#         [ 20,  39,   0],
#         ...,
#         [ 68, 103,  10],
#         [ 61,  96,   3],
#         [ 59,  94,   1]],
#
#        [[ 30,  47,   1],
#         [ 29,  46,   2],
#         [ 22,  38,   1],
#         ...,
#         [ 82, 116,  17],
#         [ 75, 110,   8],
#         [ 68, 104,   2]],
#
#        ...,
#
#        [[ 50,  46,  15],
#         [ 73,  69,  39],
#         [ 86,  82,  52],
#         ...,
#         [133, 136,  82],
#         [136, 139,  84],
#         [131, 134,  79]],
#
#        [[ 85,  79,  55],
#         [ 76,  70,  46],
#         [ 55,  47,  23],
#         ...,
#         [ 80,  79,  33],
#         [ 76,  78,  33],
#         [ 58,  59,  14]],
#
#        [[ 81,  72,  54],
#         [ 59,  50,  32],
#         [ 69,  58,  39],
# ...

# %%
plt.imshow(fix_img_2)

# %%
img3 = cv2.flip(fix_img_2, 0)
plt.imshow(img3)

# %%
img3 = cv2.flip(fix_img_2, 1)
plt.imshow(img3)

# %%
img3 = cv2.flip(fix_img_2, 3)
plt.imshow(img3)

# %%
cv2.imwrite('new genai image.jpg',img3)
# Out:
# True

# %%
pwd
# Out:
# 'C:\\Users\\A3MAX SOFTWARE TECH'
