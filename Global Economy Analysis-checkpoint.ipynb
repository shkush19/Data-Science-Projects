# %% [markdown]
# ##### Project 3 ---Global Economy Analysis

# %%
import pandas as pand

# %%
frame = pand.read_csv(r'S:\Naresh IT\27th MArch\Prakash Sir Work\DataFrame_ Pandas\data.csv')
frame  ##Reading of Dataset
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
len(frame)
# Out:
# 195

# %%
frame.columns##to fetch the column names
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
frame.columns[0]##to fetch the specific column
# Out:
# 'CountryName'

# %%
len(frame.columns)##to fetch the no of columns
# Out:
# 5

# %%
frame.head()##returns top 5 rows
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
frame.tail()##returns bottom 5 rows
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
frame.head(3)##display top 3 rows
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0        Aruba         ABW     10.244           78.9          High income
# 1  Afghanistan         AFG     35.253            5.9           Low income
# 2       Angola         AGO     45.985           19.1  Upper middle income

# %%
frame.tail(2)## returns bottom 2 rows
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 193      Zambia         ZMB     40.471           15.4  Lower middle income
# 194    Zimbabwe         ZWE     35.715           18.5           Low income

# %%
frame.info()##displays the information of the column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
frame.describe()##returns the numeric value which includes-count,mean,median-----
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
frame.describe().transpose()##transpose of a matrix from row to column and column to
##row, this is better view
# Out:
#                count       mean        std  min      25%    50%      75%  \
# BirthRate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# InternetUsers  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                    max
# BirthRate      49.6610
# InternetUsers  96.5468

# %%
frame.columns = ['m','n','o','p','q']##renaming of columns
frame.head()
# Out:
#                       m    n       o     p                    q
# 0                 Aruba  ABW  10.244  78.9          High income
# 1           Afghanistan  AFG  35.253   5.9           Low income
# 2                Angola  AGO  45.985  19.1  Upper middle income
# 3               Albania  ALB  12.877  57.2  Upper middle income
# 4  United Arab Emirates  ARE  11.044  88.0          High income

# %%
frame.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers','IncomeGroup']
frame.head()  ##assigning column names back
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %% [markdown]
# ### We see the subsetting of a dataframe in pandas---rows,columns and combine the two.

# %%
frame[12:14]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 12     Belgium         BEL      11.20        82.1702  High income
# 13       Benin         BEN      36.44         4.9000   Low income

# %%
frame[:]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
frame[:11]
# Out:
#              CountryName CountryCode  BirthRate  InternetUsers  \
# 0                  Aruba         ABW     10.244        78.9000
# 1            Afghanistan         AFG     35.253         5.9000
# 2                 Angola         AGO     45.985        19.1000
# 3                Albania         ALB     12.877        57.2000
# 4   United Arab Emirates         ARE     11.044        88.0000
# 5              Argentina         ARG     17.716        59.9000
# 6                Armenia         ARM     13.308        41.9000
# 7    Antigua and Barbuda         ATG     16.447        63.4000
# 8              Australia         AUS     13.200        83.0000
# 9                Austria         AUT      9.400        80.6188
# 10            Azerbaijan         AZE     18.300        58.7000
#
#             IncomeGroup
# 0           High income
# 1            Low income
# 2   Upper middle income
# 3   Upper middle income
# 4           High income
# 5           High income
# 6   Lower middle income
# ...

# %%
frame.head(30)
# Out:
#                  CountryName CountryCode  BirthRate  InternetUsers  \
# 0                      Aruba         ABW     10.244       78.90000
# 1                Afghanistan         AFG     35.253        5.90000
# 2                     Angola         AGO     45.985       19.10000
# 3                    Albania         ALB     12.877       57.20000
# 4       United Arab Emirates         ARE     11.044       88.00000
# 5                  Argentina         ARG     17.716       59.90000
# 6                    Armenia         ARM     13.308       41.90000
# 7        Antigua and Barbuda         ATG     16.447       63.40000
# 8                  Australia         AUS     13.200       83.00000
# 9                    Austria         AUT      9.400       80.61880
# 10                Azerbaijan         AZE     18.300       58.70000
# 11                   Burundi         BDI     44.151        1.30000
# 12                   Belgium         BEL     11.200       82.17020
# ...

# %%
frame[::-1]## reverse of the dataframe
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
frame
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
frame[::30]##this will display every 30th row
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0         Aruba         ABW     10.244          78.90          High income
# 30       Canada         CAN     10.900          85.80          High income
# 60        Gabon         GAB     30.555           9.20  Upper middle income
# 90   Kazakhstan         KAZ     22.730          54.00  Upper middle income
# 120  Mozambique         MOZ     39.705           5.40           Low income
# 150       Sudan         SDN     33.477          22.70  Lower middle income
# 180     Uruguay         URY     14.374          57.69          High income

# %%
frame.columns##display column name
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
frame['CountryCode'].head()##display top 5 country code from dataset
# Out:
# 0    ABW
# 1    AFG
# 2    AGO
# 3    ALB
# 4    ARE
# Name: CountryCode, dtype: object

# %%
['BirthRate','IncomeGroup']
# Out:
# ['BirthRate', 'IncomeGroup']

# %%
frame[['IncomeGroup','CountryCode']].head()##display 2 columns simultaneously
# Out:
#            IncomeGroup CountryCode
# 0          High income         ABW
# 1           Low income         AFG
# 2  Upper middle income         AGO
# 3  Upper middle income         ALB
# 4          High income         ARE

# %%
frame.head()##display the top 5 rows
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
frame['CountryName']##display the country Name
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: CountryName, Length: 195, dtype: object

# %%
frame[8:13][['CountryName','BirthRate']]##slicing with combining two columns
# Out:
#    CountryName  BirthRate
# 8    Australia     13.200
# 9      Austria      9.400
# 10  Azerbaijan     18.300
# 11     Burundi     44.151
# 12     Belgium     11.200

# %%
frame [['CountryName','BirthRate']][8:13]
# Out:
#    CountryName  BirthRate
# 8    Australia     13.200
# 9      Austria      9.400
# 10  Azerbaijan     18.300
# 11     Burundi     44.151
# 12     Belgium     11.200

# %%
frame_1=frame [['CountryName','BirthRate']]##creating another variable to store the 
                                               #combining result
frame_1
# Out:
#               CountryName  BirthRate
# 0                   Aruba     10.244
# 1             Afghanistan     35.253
# 2                  Angola     45.985
# 3                 Albania     12.877
# 4    United Arab Emirates     11.044
# ..                    ...        ...
# 190           Yemen, Rep.     32.947
# 191          South Africa     20.850
# 192      Congo, Dem. Rep.     42.394
# 193                Zambia     40.471
# 194              Zimbabwe     35.715
#
# [195 rows x 2 columns]

# %%
frame_1 = frame[8:13]

# %%
frame_1
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 8    Australia         AUS     13.200        83.0000          High income
# 9      Austria         AUT      9.400        80.6188          High income
# 10  Azerbaijan         AZE     18.300        58.7000  Upper middle income
# 11     Burundi         BDI     44.151         1.3000           Low income
# 12     Belgium         BEL     11.200        82.1702          High income

# %%
frame.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
frame[['CountryCode','BirthRate','InternetUsers']][8:13]##subsetting
# Out:
#    CountryCode  BirthRate  InternetUsers
# 8          AUS     13.200        83.0000
# 9          AUT      9.400        80.6188
# 10         AZE     18.300        58.7000
# 11         BDI     44.151         1.3000
# 12         BEL     11.200        82.1702

# %%
frame.BirthRate*frame.InternetUsers##using Math Operations
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Length: 195, dtype: float64

# %%
frame['Final'] = frame.BirthRate * frame.InternetUsers 
## storing value of math operations in one variable, creating of new column
frame.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup     Final
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
## removing of a new column

frame.drop('Final',axis = 1)
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
frame.columns[4]
# Out:
# 'IncomeGroup'

# %%
frame.InternetUsers>30
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 190    False
# 191     True
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
cond1 = frame.InternetUsers>30
cond1
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 190    False
# 191     True
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
cond2 = frame.InternetUsers<50
cond2
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 190     True
# 191     True
# 192     True
# 193     True
# 194     True
# Name: InternetUsers, Length: 195, dtype: bool

# %%
frame[cond1] ## this will print all the Internet users which is greaer than 30
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 0                    Aruba         ABW     10.244           78.9
# 3                  Albania         ALB     12.877           57.2
# 4     United Arab Emirates         ARE     11.044           88.0
# 5                Argentina         ARG     17.716           59.9
# 6                  Armenia         ARM     13.308           41.9
# ..                     ...         ...        ...            ...
# 184          Venezuela, RB         VEN     19.842           54.9
# 185  Virgin Islands (U.S.)         VIR     10.700           45.3
# 186                Vietnam         VNM     15.537           43.9
# 188     West Bank and Gaza         PSE     30.394           46.6
# 191           South Africa         ZAF     20.850           46.5
#
#              IncomeGroup      Final
# 0            High income   808.2516
# 3    Upper middle income   736.5644
# 4            High income   971.8720
# 5            High income  1061.1884
# ...

# %%
frame[cond2]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 1         Afghanistan         AFG     35.253            5.9
# 2              Angola         AGO     45.985           19.1
# 6             Armenia         ARM     13.308           41.9
# 11            Burundi         BDI     44.151            1.3
# 13              Benin         BEN     36.440            4.9
# ..                ...         ...        ...            ...
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup     Final
# 1             Low income  207.9927
# 2    Upper middle income  878.3135
# 6    Lower middle income  557.6052
# 11            Low income   57.3963
# 13            Low income  178.5560
# ...

# %%
cond1 & cond2## combining 2 conditions with the help of logial operator
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191     True
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
frame[cond1 & cond2]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 6                  Armenia         ARM     13.308      41.900000
# 21                  Belize         BLZ     23.092      33.600000
# 23                 Bolivia         BOL     24.236      36.940000
# 33                   China         CHN     12.100      45.800000
# 39              Cabo Verde         CPV     21.625      37.500000
# 40              Costa Rica         CRI     15.022      45.960000
# 48      Dominican Republic         DOM     21.198      45.900000
# 50                 Ecuador         ECU     21.070      40.353684
# 57                    Fiji         FJI     20.463      37.100000
# 62                 Georgia         GEO     13.332      43.300000
# 69                 Grenada         GRD     19.334      35.000000
# 73                  Guyana         GUY     18.885      35.000000
# 87                 Jamaica         JAM     13.540      37.100000
# ...

# %%
##Another way to do it
frame[(frame.InternetUsers > 30)  &  (frame.InternetUsers < 50)]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 6                  Armenia         ARM     13.308      41.900000
# 21                  Belize         BLZ     23.092      33.600000
# 23                 Bolivia         BOL     24.236      36.940000
# 33                   China         CHN     12.100      45.800000
# 39              Cabo Verde         CPV     21.625      37.500000
# 40              Costa Rica         CRI     15.022      45.960000
# 48      Dominican Republic         DOM     21.198      45.900000
# 50                 Ecuador         ECU     21.070      40.353684
# 57                    Fiji         FJI     20.463      37.100000
# 62                 Georgia         GEO     13.332      43.300000
# 69                 Grenada         GRD     19.334      35.000000
# 73                  Guyana         GUY     18.885      35.000000
# 87                 Jamaica         JAM     13.540      37.100000
# ...

# %%
income1 = frame[frame.IncomeGroup =='Upper middle income'] 
income1
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 2                            Angola         AGO     45.985      19.100000
# 3                           Albania         ALB     12.877      57.200000
# 10                       Azerbaijan         AZE     18.300      58.700000
# 16                         Bulgaria         BGR      9.200      53.061500
# 19           Bosnia and Herzegovina         BIH      9.062      57.790000
# 20                          Belarus         BLR     12.500      54.170000
# 21                           Belize         BLZ     23.092      33.600000
# 24                           Brazil         BRA     14.931      51.040000
# 28                         Botswana         BWA     25.267      15.000000
# 33                            China         CHN     12.100      45.800000
# 37                         Colombia         COL     16.076      51.700000
# 40                       Costa Rica         CRI     15.022      45.960000
# ...

# %%
income2 = frame[frame.IncomeGroup =='Lower middle income'] 
income2
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 6                  Armenia         ARM     13.308        41.9000
# 15              Bangladesh         BGD     20.142         6.6300
# 23                 Bolivia         BOL     24.236        36.9400
# 27                  Bhutan         BTN     18.134        29.9000
# 34           Cote d'Ivoire         CIV     37.320         8.4000
# 35                Cameroon         CMR     37.236         6.4000
# 36             Congo, Rep.         COG     37.011         6.6000
# 39              Cabo Verde         CPV     21.625        37.5000
# 46                Djibouti         DJI     25.486         9.5000
# 51        Egypt, Arab Rep.         EGY     28.032        29.4000
# 59   Micronesia, Fed. Sts.         FSM     23.511        27.8000
# 62                 Georgia         GEO     13.332        43.3000
# 63                   Ghana         GHA     33.131        12.3000
# ...

# %%
##Fetching unique values.

income2.IncomeGroup.unique()
# Out:
# array(['Lower middle income'], dtype=object)

# %%
income1.IncomeGroup.unique()
# Out:
# array(['Upper middle income'], dtype=object)

# %% [markdown]
# ###### Lets's get into Seaborn, which is used for advance visualization(stats)

# %%
import matplotlib.pyplot as plt # visulaiztion
import seaborn as sns # distribution visualtion

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = 10,8

#import warnings
#warnings.filterwarnings('ignore')

# %% [markdown]
# #### Now, we are analyzing all the middle class economy

# %%
income1.head()
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 2                   Angola         AGO     45.985        19.1000
# 3                  Albania         ALB     12.877        57.2000
# 10              Azerbaijan         AZE     18.300        58.7000
# 16                Bulgaria         BGR      9.200        53.0615
# 19  Bosnia and Herzegovina         BIH      9.062        57.7900
#
#             IncomeGroup       Final
# 2   Upper middle income   878.31350
# 3   Upper middle income   736.56440
# 10  Upper middle income  1074.21000
# 16  Upper middle income   488.16580
# 19  Upper middle income   523.69298

# %%
income2.head()
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup  \
# 6         Armenia         ARM     13.308          41.90  Lower middle income
# 15     Bangladesh         BGD     20.142           6.63  Lower middle income
# 23        Bolivia         BOL     24.236          36.94  Lower middle income
# 27         Bhutan         BTN     18.134          29.90  Lower middle income
# 34  Cote d'Ivoire         CIV     37.320           8.40  Lower middle income
#
#         Final
# 6   557.60520
# 15  133.54146
# 23  895.27784
# 27  542.20660
# 34  313.48800

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:364, in na_logical_op(x, y, op)
#     355 try:
#     356     # For exposition, write:
#     357     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     362     # Then Cases where this goes through without raising include:
#     363     #  (xint or xbool) and (yint or bool)
# --> 364     result = op(x, y)
#     365 except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'float' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 fc = bool(income1 & income2)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
# ...

# %%
###For Distribution graph

visual = sns.distplot(income1["InternetUsers"])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_1992\3438588081.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   visual = sns.distplot(income1["InternetUsers"])
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
visual = sns.distplot(income1["InternetUsers"],bins=15)

##Univariate Analysis
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_1992\884046989.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   visual = sns.distplot(income1["InternetUsers"],bins=15)
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # BOX PLOTS:Multivariate Analysis

# %%
visual_1 = sns.boxplot(data = income1, x="IncomeGroup", y='BirthRate')

# %%
visual_2 = sns.lmplot(data = income1,x = 'InternetUsers', y = 'BirthRate', fit_reg = False) #lm - linear model

# %%
visual_3 = sns.lmplot(data = income1,x = 'InternetUsers', y = 'BirthRate')

# %%
vis5 = sns.lmplot(data = income1,x = 'InternetUsers', y = 'BirthRate',
                  fit_reg = False,hue = 'IncomeGroup') #hue - parameter for color

# %%
vis5 = sns.lmplot(data = frame,x = 'InternetUsers', y = 'BirthRate',
                  fit_reg = False,hue = 'IncomeGroup') #hue - parameter for color
